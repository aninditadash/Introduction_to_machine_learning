# %% [markdown]
# ### __Features and Feature Engineering__

# %% [markdown]
# __Features__ represent the transformed raw data, after a process called Feature engineering. __Feature Engineering__ describes the stage which prepares the input dataset and makes it compatible with the machine learning algorithms.

# %% [markdown]
# #### __Feature Selection__

# %% [markdown]
# Feature selection is the process of reducing the number of features used in various types of machine learning models, in a way that leaves the predictive
# ability of the data preserved.
#
# - When dealing with real-world data, we can encounter hundreds or thousands of features that exceed the no. of observations. This leads to a high-dimensional dataset.
# - A set with many features probably means that the volume is large but the data points are very few and far apart.
# - This can impact the performance of the machine learning algorithm, making it unreliable.
# - In such cases, we can try to remove the irrelevant features without losing essential information from the dataset.
# - Hence, reducing the features can boost the training accuracy of the model, hence its predictive power.

# %% [markdown]
# #### __Feature Extraction__

# %% [markdown]
# Feature Extraction is the process of transforming existing features into new ones. In essence, we are not using a subset of the original features. Instead, we create new ones, a linear combination of the originals. Here, also the main goal is to capture the same information with fewer features.
#
# The difference between __feature selection__ and __feature extraction__ is that the first technique retains a subset of the original features while feature extraction generates new features.

# %% [markdown]
# #### __Dimensionality Reduction__

# %% [markdown]
# It can be described as a combination of both feature selection and feature extraction. Essentially we can lower the data dimensionality using both techniques.
#
# - When applying feature selection, working with a subset of original data indicates that we will have fewer features compared to the original dataset.
# - When applying feature extraction, although the no. of newly constructed features might be the same as the original, we usually use only the significant ones.
# - In particular, evaluating the retained variants in the dataset helps us select those features that preserve the most information for our data.

# %% [markdown]
# ## __Curse of Dimensionality__

# %% [markdown]
# It is the notion of describing a set of problems that arise if a dataset contains far more features than observations, or a high-dimensional dataset.
#
# - It refers to the difficulties we face when optimizing a function with many input variables.
# - In such cases, the error can increase when adding dimensions or similarly features to the dataset.
# - Here, the volume of the high-dimensional dataset is very large while the data points in it are few and far apart.
# - So, we are dealing with __Data Sparsity__ which impacts the performance of the machine learning algorithms and their ability to make accurate predictions.

# %% [markdown]
# - __Data Sparsity:__ As the number of dimensions increases, the data becomes increasingly spread out, making it harder to find patterns or relationships.
# - __Increased Data Requirements:__ To maintain a certain level of accuracy, the amount of data needed to effectively model or analyze high-dimensional data grows exponentially with the number of dimensions.
# - __Distance Concentration:__ In high-dimensional spaces, the relative difference between the nearest and farthest points becomes negligible, making it difficult for algorithms to distinguish between close and distant data points.
# - __Increased complexity:__ caused by the growing number of possible combinations of features.
# - There is possibility of including __more noise__ in the training data.
# - __Overfitting:__ Models can easily overfit to the noise in high-dimensional data, leading to poor generalization to new, unseen data.
# - __High Computation power:__ More dimensions mean more computational resources and time to process the data.
# - __Performance degradation:__ Algorithms, especially those relying on distance measurements like k-nearest neighbors, can see a drop in performance.
# - __Increased data storage__ due to high-dimensional data.

# %% [markdown]
# ## __Dimensionality Reduction Techniques__

# %% [markdown]
# Dimensionality reduction involves decreasing the number of features (or dimensions) in a dataset while preserving as much information as possible. This technique is used for various purposes, such as simplifying a model, enhancing the performance of a learning algorithm, or making the data easier to visualize. There are two ways to apply the dimension reduction technique, which are given below:
#
# - Feature Selection
# - Feature Extraction

# %% [markdown]
# ### __Importance of Dimensionality Reduction__

# %% [markdown]
# Dimensionality reduction is important because it:
#
# 1. **Improves computational efficiency:** Reduces the computational cost for data processing and model training.
# 2. **Mitigates the curse of dimensionality:** Simplifies data to prevent overfitting and sparsity issues.
# 3. **Reduces noise in data:** Eliminates irrelevant or noisy features to enhance model performance.
# 4. **Enhances data visualization:** Makes high-dimensional data easier to visualize in 2D or 3D.
# 5. **Boosts model performance:** Focuses on the most relevant features for better accuracy.
# 6. **Saves storage and memory:** Decreases the amount of storage and memory needed for large datasets.
# 7. **Increases model interpretability:** Simplifies models, making them easier to understand and explain.
# 8. **Avoids multicollinearity:** Addresses high correlation between features to improve regression models.

# %% [markdown]
# ### __Feature Selection__

# %% [markdown]
# Feature selection is the process of choosing a subset of relevant features and discarding irrelevant ones from a dataset to build a more accurate model. Essentially, it involves selecting the most optimal features from the input data. Three methods are used for the feature selection:
#
# 1. **Filter Methods:** this method involves filtering the dataset to retain only the relevant features. Common techniques include: `Correlation`, `Chi-Square Test`, `Variance maximisation`.
#
# 2. **Wrapper Methods:** this method evaluates subsets of features using a machine learning model. Features are added or removed based on their impact on model performance. It is more accurate but also more complex than filter methods. Common techniques include: `Forward Selection` and `Backward Selection`, `Recursive Feature Elimination (RFE)`.
#
# 3. **Embedded Methods:** these methods evaluate the importance of features during the training process of the machine learning model. Common techniques include: `LASSO`, `Elastic Net`, and `Ridge Regression`, `Decision Trees and Random Forests`.

# %% [markdown]
# #### __Feature Selection wrapper methods__

# %% [markdown]
# - Forward and backward feature selection are wrapper methods in machine learning that iteratively add or remove features based on their impact on model performance, aiming to find the optimal subset of features. __Forward selection__ starts with no features and adds the most relevant one at a time, while __backward selection__ elimination starts with all features and removes the least relevant one at a time.
# - __Recursive Feature Elimination (RFE)__ is a feature selection method that iteratively removes features based on their importance, aiming to identify the most relevant features for a machine learning model. It trains a model, ranks features, removes the least important, and repeats until a desired number of features remains.
# - __Variance Maximization__ feature selection is a technique that prioritizes features based on their ability to explain the variance in the data. It involves calculating the variance of each feature and then selecting those that have the highest variance, as features with greater variability are likely to contain more information.

# %% [markdown]
# ### __Feature Extraction__

# %% [markdown]
# Feature extraction is the process of transforming high-dimensional data into a lower-dimensional space. This approach is useful for retaining essential information while using fewer resources for processing.
#
# Some common feature extraction techniques are:
#
# - Principal Component Analysis (PCA)
# - Linear Discriminant Analysis (LDA)
# - Independent Component Analysis (ICA)

# %% [markdown]
# ## __1. Principal Component Analysis (PCA)__

# %% [markdown]
# Principal Component Analysis (PCA) is a statistical technique for dimensionality reduction in data analysis. It simplifies the complexity of high-dimensional data while preserving trends and patterns.
#
# - Real-world problems typically deal with datasets that have a huge number of features.
# - Example: High-resolution images that need classification or power allocation exercises across multiple communication channels that have high dimensionality. Dealing with such datasets demands increased computational power and more complex algorithms.
# - Principal Component Analysis (PCA) is an unsupervised learning technique used to preprocess datasets and reduce their dimensionality while preserving the original dataset. It works with numerical data.
# - The primary goal of PCA is to find a linear combination of features that maximizes the variance in the data. By doing this, PCA identifies the directions (principal components) along which the data varies the most, thus reducing the dimensionality while retaining the most important information.
# - PCA does not necessarily eliminate all correlations or transform non-linear relationships into linear ones.
# - __How many components (PCs) to keep when performing PCA in general:__ It is rule of thumb that we retain atleast __80%-90%__ of the total variance in our data.
# - __Measuring the Spread of data and how to minimise it:__ The PC axes is adjusted in a way that minimizes the distance from the points to it. PCA constructs the principal components so that they are un-correlated, meaning there is no linear relationship between them. So, the components are constructed in a way that makes the next component perpendicular to the previous.
# - __How does PCA projects the points onto the Principal components:__ Each principal component will be a linear combination of all the attributes the data points carry.
# - __Vector projection formula:__ https://www.geeksforgeeks.org/vector-projection-formula/

# %% [markdown]
# ### __How PCA Constructs the Principal Components__

# %% [markdown]
# - Principal components are constructed in such a manner that the first principal component accounts for the largest possible variance in the data set.
# - From the scatter plot below.
# - The first PC will be approximately the line that matches the purple marks because it goes through the origin and it’s the line in which the projection of the points (red dots) is the most spread out. Or mathematically speaking, it’s the line that maximizes the variance (the average of the squared distances from the projected points (red dots) to the origin).
# - The second PC is calculated in the same way, with the condition that it is uncorrelated with (i.e., perpendicular to) the first principal component and that it accounts for the next highest variance.
# - This continues until a total of p principal components have been calculated, equal to the original number of variables.
#
# <img src="https://builtin.com/sites/www.builtin.com/files/inline-images/national/Principal%2520Component%2520Analysis%2520second%2520principal.gif" width=700 />

# %% [markdown]
# ### __Common Terms in PCA__

# %% [markdown]
# - __Dimensionality:__ It is the number of features present in the data.
#
# - __Correlation:__ It indicates the strength of the relationship between features. The correlation value ranges between -1 and +1. It is -1 when variables are inversely proportional and +1 when they are directly proportional.
#
# - __Orthogonality:__ Dimensionality reduction techniques often utilize orthogonality to maintain the independence of features when reducing the number of dimensions in a dataset.
#
# - __Covariance Matrix:__ It is a matrix containing the covariance between variables.
#
# - __Variance:__ is a measure of the variability or spread of a single variable, indicating how much the values differ from the mean.
#
# - __Eigenvector:__ Given a square matrix $A$ and a nonzero vector $v$, and $v$ is the eigenvector if $Av$ (the result of applying matrix $A$ to $v$) is a scalar multiple of $v$, i.e. $Av$ = ${\lambda}v$ where ${\lambda}$ is the eigenvalue
#
# - __Eigenvalues:__ The scalar ${\lambda}$ associated with the eigenvector $v$ in the transformation $Av$ = ${\lambda}v$, indicating how much the eigenvector is scaled during the transformation. It represents the variance captured by each principal component, indicating their importance in explaining the data's variability.
#
# - __Principal component:__ Principal components are new variables created as linear combinations of the original variables, arranged to be uncorrelated and to compress most of the information into the initial components. In this way, from 10-dimensional data, PCA aims to maximize the information in the first component, then the next most in the second, and so on.

# %% [markdown]
# ### __Steps involved in PCA__

# %% [markdown]
# 1. Standardization
# 2. Covariance matrix computation
# 3. Compute the eigenvectors and eigenvalues of the covariance matrix to identify the principal components
# 4. Create a Feature vector
# 5. Recasting data along the principal component axes

# %% [markdown]
# #### __Step 1: Standardization__

# %% [markdown]
# Standardization adjusts the range of variables so that each one contributes equally, ensuring uniformity in their influence.
# Standardization transforms data by rescaling it to have a mean of 0 and a standard deviation of 1, ensuring consistent ranges and making it more suitable for comparison and analysis across different variables.
#
# $$ Z = \frac{\text{Value} - \text{mean}}{\text{Standard deviation}} $$
#
# This normalization process mitigates the dominance of variables with larger ranges over those with smaller values.

# %% [markdown]
# #### __Step 2: Covariance Matrix Computation__

# %% [markdown]
# It helps to check the correlation between features in a dataset. It helps us to understand how the variables of the input data set are varying from the mean with respect to each other, or in other words, to see if there is any relationship between them. Because sometimes, variables are highly correlated in such a way that they contain redundant information. So, in order to identify these correlations, we compute the covariance matrix.
#
# __Note:__ If all variables are independent, the off-diagonal elements (which represent covariances between different variables) would be zero. However, the diagonal elements (which represent the variances of individual variables) can still be non-zero. Therefore, the presence of non-zero values on the diagonal does not imply that the variables are not independent. Instead, independence affects the off-diagonal entries.
#
# **Types of covariance:**
#
# - Positive covariance indicates a direct correlation (the two variables increase or decrease together).
# - Negative covariance indicates an inverse correlation (one increases when the other decreases).
#
# The covariance matrix provides a summary of the relationships (correlations) between variables in a tabular representation.
#
# \begin{pmatrix}
# \text{Cov}(x, x) & \text{Cov}(x, y) \\
# \text{Cov}(y, x) & \text{Cov}(y, y)
# \end{pmatrix}

# %% [markdown]
# #### __Step 3: Identifying Principal Components by computing eigenvectors and eigenvalues of the covariance matrix__

# %% [markdown]
# Eigenvectors and eigenvalues, computed from the covariance matrix, determine the principal components of data.
#
# - __Eigenvalues__ are found by solving the characteristic equation:
#
#    $$ \text{det(C - λI)} = 0 $$
#
# where C is the Covariance Matrix, λ is the eigenvalue.
#
# - Once the eigenvalues are found, the corresponding __eigenvectors__ are determined by solving the equation
#
#   $$ \text{(C - λI) v} = 0 $$
#
# where v is the eigen vector.
#
# - Each eigenvector, paired with a corresponding eigenvalue, represents an axis direction where the data variance is maximized — these are the principal components.
# - The eigenvalues indicate the amount of variance each component carries. By ordering the eigenvectors from highest to lowest eigenvalues, you rank the principal components by their significance.
# - To compute the percentage of information accounted by each component, we divide the eigenvalue of the respective component by the sum of all eigenvalues.
#
#
# <img src="https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ML/New/Lesson_06_Unsupervised_Learning/identifying_principal_components.png" width=700 />

# %% [markdown]
# #### __Step 4: Create a Feature Vector__

# %% [markdown]
# In previous step, we computed the eigenvectors and ordered them by their eigenvalues in descending order, allowing us to find the principal components in order of significance. In this step, we decide whether to retain all components or to discard the less significant ones (those with lower eigenvalues). We then form a matrix from the remaining, more significant eigenvectors, known as the Feature Vector.
#
# So, the feature vector is simply a matrix that has columns as the eigenvectors of the components that we decide to keep. This makes it the first step towards dimensionality reduction, because if we choose to keep only `p` eigenvectors (components) out of `n`, the final data set will have only `p dimensions`.

# %% [markdown]
# #### __Step 5: Recast the Data Along the Principal Components Axes__

# %% [markdown]
# Here, the aim is to use the feature vector formed using the eigenvectors of the covariance matrix, to reorient the data from the original axes to the ones represented by the principal components (hence the name Principal Components Analysis).
#
# $$ \text{FinalDataSet} = \text{FeatureVector}^T \times \text{OriginalDataSet}^T $$
#
# This is done by multiplying the transpose of the feature vector by the transpose of the original dataset.
#
# <img src="https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/89/56/2-1_orthogonal-relshp_pc1-pc2-1.png" width=600 />

# %% [markdown]
# #### __Scree Plot__

# %% [markdown]
# A scree plot is a graphical tool used in statistical analysis, particularly in principal component analysis (PCA), to help determine the number of components to retain in a model. It is a line plot of the eigenvalues of the components or factors, with the x-axis representing the component number and the y-axis representing the eigenvalue.

# %% [markdown]
# #### __Advantages of PCA__

# %% [markdown]
# - __Multicollinearity Handling:__ Creates new, uncorrelated variables to address issues when original features are highly correlated.
# - __Noise Reduction:__ Eliminates components with low variance enhance data clarity.
# - __Data Compression:__ Represents data with fewer components reduce storage needs and speeding up processing.
# - __Outlier Detection:__ Identifies unusual data points by showing which ones deviate significantly in the reduced space.

# %% [markdown]
# #### __Disadvantages of PCA__

# %% [markdown]
# - __Interpretation Challenges:__ The new components are combinations of original variables which can be hard to explain.
# - __Data Scaling Sensitivity:__ Requires proper scaling of data before application or results may be misleading.
# - __Information Loss:__ Reducing dimensions may lose some important information if too few components are kept.
# - __Assumption of Linearity:__ Works best when relationships between variables are linear and may struggle with non-linear data.
# - __Computational Complexity:__ Can be slow and resource-intensive on very large datasets.
# - __Risk of Overfitting:__ Using too many components or working with a small dataset might lead to models that don't generalize well.

# %% [markdown]
# ### __Implementation of PCA on the Breast Cancer Dataset__

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
import plotly.express as px

# %%
data = load_breast_cancer()
df = pd.DataFrame(data=data.data, columns=data.feature_names)
df['target'] = data.target
df.columns = df.columns.str.lower().str.replace(' ', '_')
df
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data['target_names']
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %% [markdown]
# ##### __Observation:__
#
# - Here, the `target` column contains 2 values 0 and 1.
# - `0` -> Malignant tumor
# - `1` -> Benign tumor
# - __Note:__ "malignant" means cancerous, while "benign" means non-cancerous.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean_radius              569 non-null    float64
#  1   mean_texture             569 non-null    float64
#  2   mean_perimeter           569 non-null    float64
#  3   mean_area                569 non-null    float64
#  4   mean_smoothness          569 non-null    float64
#  5   mean_compactness         569 non-null    float64
#  6   mean_concavity           569 non-null    float64
#  7   mean_concave_points      569 non-null    float64
#  8   mean_symmetry            569 non-null    float64
#  9   mean_fractal_dimension   569 non-null    float64
#  10  radius_error             569 non-null    float64
#  11  texture_error            569 non-null    float64
#  12  perimeter_error          569 non-null    float64
# ...

# %%
df.dtypes.value_counts()
# Out:
# float64    30
# int64       1
# Name: count, dtype: int64

# %%
# check for missing values
missing_values = df.isna().sum()
missing_values
# Out:
# mean_radius                0
# mean_texture               0
# mean_perimeter             0
# mean_area                  0
# mean_smoothness            0
# mean_compactness           0
# mean_concavity             0
# mean_concave_points        0
# mean_symmetry              0
# mean_fractal_dimension     0
# radius_error               0
# texture_error              0
# perimeter_error            0
# area_error                 0
# smoothness_error           0
# compactness_error          0
# concavity_error            0
# concave_points_error       0
# symmetry_error             0
# fractal_dimension_error    0
# worst_radius               0
# worst_texture              0
# worst_perimeter            0
# worst_area                 0
# worst_smoothness           0
# worst_compactness          0
# worst_concavity            0
# worst_concave_points       0
# worst_symmetry             0
# worst_fractal_dimension    0
# target                     0
# dtype: int64

# %%
# Check for duplicate values
duplicate_values = df.duplicated().sum()
duplicate_values
# Out:
# 0

# %% [markdown]
# ##### __Observation:__
#
# - There are no missing or duplicate values in the dataset.
# - The dataset has only numerical values - float and int.

# %%
df.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter    mean_area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
# Plot heatmap to check the correlation between columns

# Calculate correlation matrix for numeric columns only
correlation_matrix = df.iloc[:,0:30].corr(numeric_only=True)

plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".1f")
plt.title('Heatmap of Correlation Matrix (Breast Cancer Dataset)')
plt.show()

# %% [markdown]
# ##### __Observation:__
#
# - Here, we can observe multi-collinearity amongst the columns, where many columns have a correlation of above 0.5.

# %%
# Extract the feature(s) from the DataFrame (X)
X = df.drop(['target'], axis=1)

# Extract the target variable from the DataFrame (y)
y = df['target']

# %%
X.shape
# Out:
# (569, 30)

# %%
# Standardize the data
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
X_std.shape
# Out:
# (569, 30)

# %% [markdown]
# #### __Performing PCA (without reducing components)__

# %% [markdown]
# - PCA will construct exactly as many PCs as the dimension of the data if we donot specify a precise number.
# - So, for the above example, since we have 30 features (numerical columns), PCA will create 30 components or PCs.
# - `pca.fit_transform()` takes the variance and standard deviation of the data and standardizes it.
# - We will then analyse the variance captured by each principal component.
# - And then choose a subset of components that captures enough variance (threshold = 80-90% variance)(_in a later step_).
# - We can check the variance carried by each principal component. `pca.explained_variance_ratio_` returns an array of the variance ratios. Here, the variance values in the feature vectors decreases by increasing their index.
# - We can also check the cummulative variance. __Cummulative variance is the variance in the data captured up until a certain component.__

# %%
pca = PCA()
pca.fit(X_std)
# Out:
# PCA()

# %%
pca.explained_variance_
# Out:
# array([1.33049908e+01, 5.70137460e+00, 2.82291016e+00, 1.98412752e+00,
#        1.65163324e+00, 1.20948224e+00, 6.76408882e-01, 4.77456255e-01,
#        4.17628782e-01, 3.51310875e-01, 2.94433153e-01, 2.61621161e-01,
#        2.41782421e-01, 1.57286149e-01, 9.43006956e-02, 8.00034045e-02,
#        5.95036135e-02, 5.27114222e-02, 4.95647002e-02, 3.12142606e-02,
#        3.00256631e-02, 2.74877113e-02, 2.43836914e-02, 1.80867940e-02,
#        1.55085271e-02, 8.19203712e-03, 6.91261258e-03, 1.59213600e-03,
#        7.50121413e-04, 1.33279057e-04])

# %%
pca.explained_variance_ratio_
# Out:
# array([4.42720256e-01, 1.89711820e-01, 9.39316326e-02, 6.60213492e-02,
#        5.49576849e-02, 4.02452204e-02, 2.25073371e-02, 1.58872380e-02,
#        1.38964937e-02, 1.16897819e-02, 9.79718988e-03, 8.70537901e-03,
#        8.04524987e-03, 5.23365745e-03, 3.13783217e-03, 2.66209337e-03,
#        1.97996793e-03, 1.75395945e-03, 1.64925306e-03, 1.03864675e-03,
#        9.99096464e-04, 9.14646751e-04, 8.11361259e-04, 6.01833567e-04,
#        5.16042379e-04, 2.72587995e-04, 2.30015463e-04, 5.29779290e-05,
#        2.49601032e-05, 4.43482743e-06])

# %%
# Creating a bar chart to check the variance carried by each principal component

plt.figure(figsize=(11,6))
var_exp = pca.explained_variance_ratio_
plt.bar(range(1, len(pca.explained_variance_ratio_) + 1), var_exp, color='#0e6655')
plt.title('Explained variance by principal components')
plt.xlabel('Principal components')
plt.ylabel('Explained variance ratio')
plt.grid()
plt.show()

# %%
# Create a chart to check the cummulative variance of the PCs

plt.figure(figsize=(11,6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--', color='darkblue')
plt.title('Explained variance by principal components')
plt.xlabel('No. of components')
plt.ylabel('Cummulative explained variance')
plt.grid()
plt.show()

# %% [markdown]
# ##### __Observation:__
#
# - Now, we must decide how many principal components to choose to explain atleast 80-90% of the total variance.
# - From the above cummulative distribution graph we can observe that the first `7` points will give us around 90% of the variance, so we will pick the first 7 components as they will provide a cummulative variance of above 80% which will satisfy the threshold variance limit.

# %% [markdown]
# #### __Performing PCA (with 7 PCs)__

# %% [markdown]
# - The next task will be to interpret these components and their relationship to the original features.
# - Since, each component is a combination of our initial variables, we must find those with the biggest weights in the equation of each component or which variables describe each of our components best.
# - Now, we will apply PCA with 7 components on the standardized data.
# - Then, we will find the correlations between each of the components (`pca.components_`) and each of the variables.
# - `pca.transform()` will project the standardized data points onto the PCs.

# %%
pca = PCA(n_components=7)
pca.fit(X_std)
# Out:
# PCA(n_components=7)

# %%
pca.components_.shape
# Out:
# (7, 30)

# %%
pca_df = pd.DataFrame(data=pca.components_,  
                      columns=X.columns.values,
                     index=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7'])
pca_df
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# PC1     0.218902      0.103725        0.227537   0.220995         0.142590
# PC2    -0.233857     -0.059706       -0.215181  -0.231077         0.186113
# PC3    -0.008531      0.064550       -0.009314   0.028700        -0.104292
# PC4    -0.041409      0.603050       -0.041983  -0.053434        -0.159383
# PC5    -0.037786      0.049469       -0.037375  -0.010331         0.365089
# PC6     0.018741     -0.032179        0.017308  -0.001888        -0.286374
# PC7    -0.124088      0.011400       -0.114477  -0.051653        -0.140669
#
#      mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# PC1          0.239285        0.258400             0.260854       0.138167
# PC2          0.151892        0.060165            -0.034768       0.190349
# PC3         -0.074092        0.002734            -0.025564      -0.040240
# ...

# %%
# Plot heatmap to check the covariance matrix
plt.figure(figsize=(12,8))
sns.heatmap(pca_df, vmin=-1, vmax=1, annot=True, cmap='coolwarm', fmt=".1f")
plt.title('Heatmap of Covariance Matrix (PC vs Features)')
plt.show()

# %% [markdown]
# ##### __Observation:__
#
# - After performing PCA and choosing 7 principal components, we can observe that the correlation between these components and the features reduces by a significant amount.
# - Here, we can observe that the multi-collinearity amongst the columns has been reduced.

# %% [markdown]
# #### __Performing PCA (with 3 PCs) - 3D system__

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_std)

# %%
X_pca.shape
# Out:
# (569, 3)

# %%
df_pca = pd.DataFrame(data=X_pca, columns=['Principal Component 1', 'Principal Component 2', 'Principal Component 3'])
df_pca['Target'] = y

# %%
# Create a 3D scatter plot

fig = plt.figure(figsize=(13, 5))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

colors = ['r', 'b']
for target, color in zip([0, 1], colors):
    indices = df_pca['Target'] == target
    ax.scatter(df_pca.loc[indices, 'Principal Component 1'],
               df_pca.loc[indices, 'Principal Component 2'],
               df_pca.loc[indices, 'Principal Component 3'],
               c=color,
               s=50)

# Set labels
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')

ax.legend(['Malignant', 'Benign'])
ax.set_title('PCA of Breast Cancer Dataset')
ax.set_box_aspect(None, zoom=0.85)

# Show the plot
plt.show()

# %%
y_str = y.astype(str)
plt.figure(figsize=(11,9))
fig = px.scatter_3d(x=X_pca[:,0], 
                    y=X_pca[:,1], 
                    z=X_pca[:,2],
                    color=y_str
                   )
fig.update_layout(
    margin=dict(l=20, r=20, t=20, b=20),
    paper_bgcolor="LightSteelBlue",
    scene=dict(
        xaxis_title="PC 1",
        yaxis_title="PC 2",
        zaxis_title="PC 3",
    ),
    title_text='PCA of Breast Cancer Dataset'
)
fig.show()
# Out:
# <div>                            <div id="1f016f47-cb7b-47e8-b04a-5e4a2c03c242" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f016f47-cb7b-47e8-b04a-5e4a2c03c242")) {                    Plotly.newPlot(                        "1f016f47-cb7b-47e8-b04a-5e4a2c03c242",                        [{"hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":[9.192836826213238,2.3878017958022153,5.733896279731704,7.122953197708876,3.9353020736780975,2.3802471503459324,2.238883308052404,2.1432985003775444,3.17492429308373,6.351746789526088,-0.8104137708452942,2.651
# ...

# %% [markdown]
# #### __Performing PCA (with 2 PCs) - 2D system__

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
X_pca.shape
# Out:
# (569, 2)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], data=df, hue='target', palette ='Set1')

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Scatter plot: PC1 vs PC2')

plt.grid()
plt.show()

# %% [markdown]
# ## __2. Linear Discriminant Analysis (LDA)__

# %% [markdown]
# Linear discriminant analysis (LDA) is a technique used for dimensionality reduction and classification. It aims to project the data onto a lower-dimensional space from a high-dimensional space in such a way that the separation between different classes is maximized. LDA focuses on finding a linear combination of features that best separate two or more classes of objects or events.
#
# - The goal of LDA is to find a linear combination of features to best separate two or more classes.
# - While PCA is an unsupervised learning technique, LDA is a supervised machine learning algorithm.
# - When LDA is performed, it constructs new axes called linear discriminants where the data is being projected.
# - LDA tries to maximise the distances between the classes. At the same time, it also tries to make each individual class as dense and compact as possible in order to lower the variance of data within each class.
# - In LDA, the no. of linear discriminants is at most `C - 1`, where `C` is the no. of distinct classes in the dataset.
# - The goal is to maximise class separability amongst our dataset, i.e. constructing axes that better separate the data points according to their labels and into well-formed clusters.
#
# https://www.ibm.com/think/topics/linear-discriminant-analysis
#
# <img src="https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/f1/55/applying-linear-discriminant-analysis-lda-to-a-data-cluster.png" width=600 />

# %% [markdown]
# - LDA does this by projecting data with two or more dimensions into one dimension so that it can be more easily classified.
# - The technique is, therefore, sometimes referred to as dimensionality reduction.
# - This versatility ensures that LDA can be used for multi-class data classification problems, unlike logistic regression, which is limited to binary classification.
# - LDA is thus often applied to enhance the operation of other learning classification algorithms such as decision tree, random forest or support vector machines (SVM).
# - Uses Fisher's method to identify a linear combination of features that discriminates between two or more classes of labeled objects or events.
# - Fisher’s method reduces dimensions by separating classes of projected data.
# - Separation means maximizing the distance between the projected means and minimizing the projected variance within classes.
# - To create new axis and reduce dimensionality, __LDA follows these criteria__:
#   1. Maximize the distance between the means of two classes.
#   2. Minimize the variance within individual classes.

# %% [markdown]
# - LDA assumes the data follows a Gaussian distribution.
# - It assumes that the covariance matrices of different classes are equal.
# - It assumes the data is linearly separable, allowing for an accurate linear decision boundary to classify different classes.
# - It can reduce the dimensionality of the data to a maximum of $𝑘 − 1$ components, where $k$ is the number of classes in the target variable.
# - __Dimensionality reduction using LDA can help improve the performance of a classifier by reducing the effect of noise and preventing
# overfitting to the training data.__
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*lFVtoScmRFoKFLwK8fcKRQ.png" width=600 height=500 />

# %% [markdown]
# #### __Role of eigenvectors and eigenvalues__

# %% [markdown]
# - Dimensionality reduction involves separating data points with a straight line.
# - Mathematically, linear transformations are analyzed using eigenvectors and eigenvalues.
# - Imagine you have mapped out a data set with multiple features, resulting in a multi-dimensional scatterplot.
# - Eigenvectors provide the "direction" within the scatterplot, and eigenvalues denote the importance of this directional data.
# - During dimensionality reduction, the eigenvectors are calculated from the data set and collected in two scatter-matrices:
#   1. __Between-class scatter matrix__ (information about the data spread within each class). $S_B$ - Measures the scatter of the class means around the overall mean.
#   2. __Within-class scatter matrix__ (how classes are spread between themselves). $S_W$ - Measures the scatter of data points within each class around their respective means.

# %% [markdown]
# - __Between-class variance:__ The between-class variance is the separability between classes — the distance between the class means.
# - __Within-class variance:__ The within-class variance is the distance between class means and samples.
# - We can find the eigenvalues and eigenvectors of the matrix obtained from:
#     $$ {{S_W}^{-1}} \times {S_B} $$
#   where $ {{S_W}^{-1}} $ is the inverse of $ {S_W} $.
# - These eigenvectors are the linear discriminants or axes of our low-dimensional space.

# %% [markdown]
# <img src="https://editor.analyticsvidhya.com/uploads/75127Facebook%20post%20-%201.png" width=500 />

# %% [markdown]
# #### __Advantages of LDA__

# %% [markdown]
# - Simple and computationally efficient.
# - LDA is effective where the number of features is larger than the number of training samples. Therefore, LDA is valuable in applications such as text analysis, image recognition and genomics, where data is often high-dimensional.
# - Can handle multicollinearity.

# %% [markdown]
# #### __Disadvantages of LDA__

# %% [markdown]
# - Assumes Gaussian distribution of data which may not always be the case.
# - Assumes equal covariance matrices for different classes which may not hold in all datasets.
# - Assumes linear separability which is not always true.
# - May not always perform well in high-dimensional feature spaces.
# - Since it is dependent on mean, it will be sensitive to outliers.

# %% [markdown]
# #### __What metrics LDA takes into account when constructing axes__

# %% [markdown]
# 1. Compute the mean of each class. $\mu_1$ and $\mu_2$
# 2. Computes $S_W$, measuring data spread or scatter within the class and then compute $S_B$, measuring scatter between classes.
# 3. Maximise the distance between class means. $\mu_1$ and $\mu_2$
# 4. Minimise the variation within each category. ${S_1}^2$ and ${S_2}^2$. This variation is called __scatter__, which measures the spread of data around the mean.
# 5. Fisher's Discrimant Ratio: $$ \frac{({\mu_1 - \mu_2})^2}{{{S_1}^2} + {{S_2}^2}} $$
# 6. Here, we need to maximise the numerator and minimise the denominator.
# 7. For multi-class classification, we will first find the overall mean (centroid). Then measure the distance between each class mean and the overall mean and the aim is to maximise it while minimising the scatter for each category.

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT5XlcTA9RE3VKWIY7BkzFtgr0qTl_7XU3hLg&s" width=300 />

# %% [markdown]
# ### __Implementation of LDA on the Breast Cancer Dataset__

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lda = LDA(n_components=1)
X_lda = lda.fit_transform(X_std, y)

# %%
X_lda.shape
# Out:
# (569, 1)

# %%
df_X_lda = pd.DataFrame(data=X_lda, columns=['LDA Component 1'])
df_X_lda['Target'] = y

# %%
colors = ['r', 'b']
plt.figure(figsize=(8, 6))
for target, color in zip([0, 1], colors):
    indices = df_X_lda['Target'] == target
    plt.scatter(df_X_lda.loc[indices, 'LDA Component 1'], 
                np.zeros_like(df_X_lda.loc[indices, 'LDA Component 1']),
                c=color,
                alpha=0.85,
                s=50)

plt.xlabel('LDA Discriminant 1')
plt.ylabel('Constant zero line')
plt.legend(['Malignant', 'Benign'])
plt.title("LDA with 1 Discriminant (Breast Cancer dataset)")

plt.grid()
plt.show()

# %% [markdown]
# ## __Comparison of LDA and PCA 2D projection of `Iris` dataset__
#
# - Classify iris plants into three species.
# - It includes three iris species with 50 samples each as well as some properties about each flower.
# - One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.

# %% [markdown]
# The columns in this dataset are:
# - Id
# - SepalLengthCm
# - SepalWidthCm
# - PetalLengthCm
# - PetalWidthCm
# - Species

# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
target_names = data.target_names
capitalize_name = lambda x: np.char.capitalize(x)
species = capitalize_name(target_names)
species
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype='<U10')

# %%
df['target'] = pd.Series(data.target)
X = df.iloc[: ,:4]
y = df['target']

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### __Performing PCA (with 2 PCs)__

# %%
pca = PCA(n_components=2)
iris_pca = pca.fit_transform(X)

# %%
plt.figure(figsize=(8,6))

# Define a custom palette
palette = {0: "red", 1: "green", 2: "blue"}

ax = sns.scatterplot(x=iris_pca[:,0], y=iris_pca[:,1], data=df, hue='target', palette=palette)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Scatter plot: Principal Component 1 vs Principal Component 2')

# Modify legend labels
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, species)

# Move the legend to the upper right corner
sns.move_legend(ax, loc="lower right")

plt.grid()
plt.show()

# %% [markdown]
# ### __Performing LDA (with 2 linear discriminants)__
#
# - Here, since there are 3 classes, a maximum of 2 linear discriminants can be created.

# %%
lda = LDA(n_components=2)
iris_lda = lda.fit_transform(X, y)

# %%
plt.figure(figsize=(8,6))

# Define a custom palette
palette = {0: "red", 1: "green", 2: "blue"}

ax = sns.scatterplot(x=iris_lda[:,0], y=iris_lda[:,1], data=df, hue='target', palette=palette)

plt.xlabel('Linear Discriminant 1')
plt.ylabel('Linear Discriminant 2')
plt.title('LDA Scatter plot: Linear Discriminant 1 vs Linear Discriminant 2')

# Modify legend labels
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, species)

# Move the legend to the upper right corner
sns.move_legend(ax, loc="lower right")

plt.grid()
plt.show()

# %% [markdown]
# #### __Observation:__
#
# - LDA maximizes the distance between different classes, whereas PCA maximizes the variance of the data.
# - When there are fewer samples in each class, PCA performs better.
# - LDA, however, performs better on large datasets with many classes.
